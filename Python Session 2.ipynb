# %%
import pandas as pd
df = pd.read_csv("Raw Data.csv")
df.head()

# %%
df.info()

# %%
df.columns

# %%
df.shape

# %%
df.isnull().sum()

# %%
df.tail()

# %%
df['Profit_Margin'] = df['Profit'] / df['Sales_Value']

# %%
import pandas as pd
#Convert the Date into Date-Time format
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%y')
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %%
df['Month_Name'] = df['Date'].dt.strftime('%b')

# %%
cols = list(df.columns)
cols.remove('Month_Name')
cols.insert(-3,'Month_Name')
df = df[cols]

# %%
df.head()
# Out:
#         Date Region     Product  Sales_Value  Profit  Profit_Margin  \
# 0 2024-03-12   West     Bananas      1793.49  618.84       0.345048
# 1 2024-03-16   East     Bananas      2009.14  484.19       0.240994
# 2 2024-02-01   West  Headphones       186.01   22.32       0.119994
# 3 2024-01-24  South  Headphones      1792.82  206.72       0.115304
# 4 2024-02-19  North      Tablet      2795.35  941.72       0.336888
#
#   Month_Name  Day  Month  Year
# 0        Mar   12      3  2024
# 1        Mar   16      3  2024
# 2        Feb    1      2  2024
# 3        Jan   24      1  2024
# 4        Feb   19      2  2024
